# %% [markdown]
# # PANDAS

# %% [markdown]
# Importing Pandas

# %%
import pandas
print(pandas.__version__)
# Out:
# 1.4.2

# %%
import pandas as pd
data=pd.read_csv('Advertising.csv')
print(data)
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
data
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df=pd.DataFrame(data)
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
data.shape
# Out:
# (200, 5)

# %%
data.size
# Out:
# 1000

# %% [markdown]
# Creating DataFrames..

# %%
import pandas as pd
college={'name':['venky','shyam','chandu','vinay','hemanth','bramaji','kishore'],'roll.no':[503,505,519,529,539,528,514],
        'percentage':[56,35,39,59,39,95,94]}
data=pd.DataFrame(college)
print(data)
# Out:
#       name  roll.no  percentage
# 0    venky      503          56
# 1    shyam      505          35
# 2   chandu      519          39
# 3    vinay      529          59
# 4  hemanth      539          39
# 5  bramaji      528          95
# 6  kishore      514          94

# %%
data
# Out:
#       name  roll.no  percentage
# 0    venky      503          56
# 1    shyam      505          35
# 2   chandu      519          39
# 3    vinay      529          59
# 4  hemanth      539          39
# 5  bramaji      528          95
# 6  kishore      514          94

# %%
data.size
# Out:
# 21

# %%
data.shape
# Out:
# (7, 3)

# %%
import pandas as pd
college=[('venky',592,49),('chandu',505,94),('shyam',593,59),('kishore',529,84),('vinay',518,49)]
data=pd.DataFrame(college)
data
# Out:
#          0    1   2
# 0    venky  592  49
# 1   chandu  505  94
# 2    shyam  593  59
# 3  kishore  529  84
# 4    vinay  518  49

# %%
data.size
# Out:
# 15

# %%
data.shape
# Out:
# (5, 3)

# %% [markdown]
# Indexing Slicing

# %% [raw]
# 1.data_frame.head() ------> Heading Records the rows print
# 2.data_frame.tail() ------> Last records print
# 3.data_frame.describe ----> mean,count,std,min,max,25%,..etc....
# 4.data_frame.shape -----> no.of rows and columns count
# 5.data_frame.size ------> no.of cells
# 6.data_frame[start:stop:step] ------> no.of start row and stop and gap/space
# 7.data_frame[column_name] -----> print the column name
# 8.data_frame[[column_name-1,column_2]] ------> 2 columns are print
# 9.data_frame[[column_name-1,column_2]][start:stop:step] ------> column gap and the print
# 10.data_frame.iterrows() -----> rows information print

# %%
df.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.head(11)
# Out:
#     Unnamed: 0     TV  radio  newspaper  sales
# 0            1  230.1   37.8       69.2   22.1
# 1            2   44.5   39.3       45.1   10.4
# 2            3   17.2   45.9       69.3    9.3
# 3            4  151.5   41.3       58.5   18.5
# 4            5  180.8   10.8       58.4   12.9
# 5            6    8.7   48.9       75.0    7.2
# 6            7   57.5   32.8       23.5   11.8
# 7            8  120.2   19.6       11.6   13.2
# 8            9    8.6    2.1        1.0    4.8
# 9           10  199.8    2.6       21.2   10.6
# 10          11   66.1    5.8       24.2    8.6

# %%
df.tail()
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
df.tail(11)
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 189         190   18.7   12.1       23.4    6.7
# 190         191   39.5   41.1        5.8   10.8
# 191         192   75.5   10.8        6.0    9.9
# 192         193   17.2    4.1       31.6    5.9
# 193         194  166.8   42.0        3.6   19.6
# 194         195  149.7   35.6        6.0   17.3
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
df.describe()
# Out:
#        Unnamed: 0          TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
df.shape
# Out:
# (200, 5)

# %%
df.shape
# Out:
# (200, 5)

# %%
df.size
# Out:
# 1000

# %%
df[2:22:2]
# Out:
#     Unnamed: 0     TV  radio  newspaper  sales
# 2            3   17.2   45.9       69.3    9.3
# 4            5  180.8   10.8       58.4   12.9
# 6            7   57.5   32.8       23.5   11.8
# 8            9    8.6    2.1        1.0    4.8
# 10          11   66.1    5.8       24.2    8.6
# 12          13   23.8   35.1       65.9    9.2
# 14          15  204.1   32.9       46.0   19.0
# 16          17   67.8   36.6      114.0   12.5
# 18          19   69.2   20.5       18.3   11.3
# 20          21  218.4   27.7       53.4   18.0

# %%
df[3:33:3]
# Out:
#     Unnamed: 0     TV  radio  newspaper  sales
# 3            4  151.5   41.3       58.5   18.5
# 6            7   57.5   32.8       23.5   11.8
# 9           10  199.8    2.6       21.2   10.6
# 12          13   23.8   35.1       65.9    9.2
# 15          16  195.4   47.7       52.9   22.4
# 18          19   69.2   20.5       18.3   11.3
# 21          22  237.4    5.1       23.5   12.5
# 24          25   62.3   12.6       18.3    9.7
# 27          28  240.1   16.7       22.9   15.9
# 30          31  292.9   28.3       43.2   21.4

# %%
df['Unnamed: 0']
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 195    196
# 196    197
# 197    198
# 198    199
# 199    200
# Name: Unnamed: 0, Length: 200, dtype: int64

# %%
df[['Unnamed: 0','TV','radio']]
# Out:
#      Unnamed: 0     TV  radio
# 0             1  230.1   37.8
# 1             2   44.5   39.3
# 2             3   17.2   45.9
# 3             4  151.5   41.3
# 4             5  180.8   10.8
# ..          ...    ...    ...
# 195         196   38.2    3.7
# 196         197   94.2    4.9
# 197         198  177.0    9.3
# 198         199  283.6   42.0
# 199         200  232.1    8.6
#
# [200 rows x 3 columns]

# %%
df[['Unnamed: 0','radio']][10:200:10]
# Out:
#      Unnamed: 0  radio
# 10           11    5.8
# 20           21   27.7
# 30           31   28.3
# 40           41   22.3
# 50           51    3.1
# 60           61    2.0
# 70           71   30.6
# 80           81   26.7
# 90           91    4.9
# 100         101    4.3
# 110         111    8.2
# 120         121   26.8
# 130         131   39.6
# 140         141   17.0
# 150         151   13.9
# 160         161   18.1
# 170         171   11.6
# 180         181    2.6
# 190         191   41.1

# %%
df.iterrows()
# Out:
# <generator object DataFrame.iterrows at 0x000002B1CC2F7C10>

# %%
for rec in df.iterrows():
    print(rec)
# Out:
# (0, Unnamed: 0      1.0
# TV            230.1
# radio          37.8
# newspaper      69.2
# sales          22.1
# Name: 0, dtype: float64)
# (1, Unnamed: 0     2.0
# TV            44.5
# radio         39.3
# newspaper     45.1
# sales         10.4
# Name: 1, dtype: float64)
# (2, Unnamed: 0     3.0
# TV            17.2
# radio         45.9
# newspaper     69.3
# sales          9.3
# Name: 2, dtype: float64)
# (3, Unnamed: 0      4.0
# TV            151.5
# radio          41.3
# newspaper      58.5
# sales          18.5
# Name: 3, dtype: float64)
# (4, Unnamed: 0      5.0
# TV            180.8
# radio          10.8
# newspaper      58.4
# sales          12.9
# Name: 4, dtype: float64)
# (5, Unnamed: 0     6.0
# TV             8.7
# radio         48.9
# newspaper     75.0
# sales          7.2
# Name: 5, dtype: float64)
# (6, Unnamed: 0     7.0
# TV            57.5
# radio         32.8
# newspaper     23.5
# sales         11.8
# Name: 6, dtype: float64)
# (7, Unnamed: 0      8.0
# ...

# %% [markdown]
# UNDERSTANDING LOC[] (stop index included)

# %% [raw]
# 1.data_frame.loc(row_number) ----> to print the row number of data
# 2.data-frame.loc[row_number,['column_name','column_name',----]] ----> to print rows and column data
# 3.data_frame.loc[start:stop] ------> data start the stop
# 4.data_frame.loc[start:stop,['column_1','column_2'-----]]
# 5.data_frame.loc[start,'column_name']
# 6.data_frame.loc[start:stop,'column-1': 'column_n']

# %%
df.loc[4]
# Out:
# Unnamed: 0      5.0
# TV            180.8
# radio          10.8
# newspaper      58.4
# sales          12.9
# Name: 4, dtype: float64

# %%
df.loc[4,['TV','radio','sales']]
# Out:
# TV       180.8
# radio     10.8
# sales     12.9
# Name: 4, dtype: float64

# %%
df.loc[0:4]
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.loc[4,'radio']
# Out:
# 10.8

# %%
df.loc[3:10,['TV','radio']]
# Out:
#        TV  radio
# 3   151.5   41.3
# 4   180.8   10.8
# 5     8.7   48.9
# 6    57.5   32.8
# 7   120.2   19.6
# 8     8.6    2.1
# 9   199.8    2.6
# 10   66.1    5.8

# %%
df.loc[3:10,'Unnamed: 0': 'newspaper']
# Out:
#     Unnamed: 0     TV  radio  newspaper
# 3            4  151.5   41.3       58.5
# 4            5  180.8   10.8       58.4
# 5            6    8.7   48.9       75.0
# 6            7   57.5   32.8       23.5
# 7            8  120.2   19.6       11.6
# 8            9    8.6    2.1        1.0
# 9           10  199.8    2.6       21.2
# 10          11   66.1    5.8       24.2

# %% [markdown]
# UNDERSTANDING ILOC[] (stop index excluded)

# %% [raw]
# 1.data_frame.iloc[row_number,column_number]
# 2.data_frame.iloc[row-start:row_stop,column_start:column_stop]
# 3.data-frame.iloc[start:stop,column_number]
# 4.data_frame.iloc[[row_1,row_2,----]]
# 5.data_frame.iloc[:,[colum_1,column_2,----]]
# 6.data_frame.iloc[start:stop,[column-1,column-2,-----]]

# %%
df.iloc[4,2]
# Out:
# 10.8

# %%
df.iloc[1:3,2:20]
# Out:
#    radio  newspaper  sales
# 1   39.3       45.1   10.4
# 2   45.9       69.3    9.3

# %%
df.iloc[1:3,3]
# Out:
# 1    45.1
# 2    69.3
# Name: newspaper, dtype: float64

# %%
df.iloc[[1,3,25,83,189]]
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 1             2   44.5   39.3       45.1   10.4
# 3             4  151.5   41.3       58.5   18.5
# 25           26  262.9    3.5       19.5   12.0
# 83           84   68.4   44.5       35.6   13.6
# 189         190   18.7   12.1       23.4    6.7

# %%
df.iloc[:,[1,3]]
# Out:
#         TV  newspaper
# 0    230.1       69.2
# 1     44.5       45.1
# 2     17.2       69.3
# 3    151.5       58.5
# 4    180.8       58.4
# ..     ...        ...
# 195   38.2       13.8
# 196   94.2        8.1
# 197  177.0        6.4
# 198  283.6       66.2
# 199  232.1        8.7
#
# [200 rows x 2 columns]

# %%
df.head(10).iloc[2:19,[1,2]]
# Out:
#       TV  radio
# 2   17.2   45.9
# 3  151.5   41.3
# 4  180.8   10.8
# 5    8.7   48.9
# 6   57.5   32.8
# 7  120.2   19.6
# 8    8.6    2.1
# 9  199.8    2.6

# %% [markdown]
# SORTING DATAFRAMES

# %% [raw]
# 1.data_frame.sort_values("column_name")
# 2.data_frame.sort_values('column_name',ascending=false) ----> descending order follows
# 3.data_frame.sort_values(['column-1','column_2])
# 4.data_frame.sort_values(['column_1','column_2'],ascending=[0,1]) ------> descending order follows

# %%
df.sort_values('TV')
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 8           9    8.6    2.1        1.0    4.8
# 5           6    8.7   48.9       75.0    7.2
# 2           3   17.2   45.9       69.3    9.3
# 1           2   44.5   39.3       45.1   10.4
# 6           7   57.5   32.8       23.5   11.8
# 7           8  120.2   19.6       11.6   13.2
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9
# 9          10  199.8    2.6       21.2   10.6
# 0           1  230.1   37.8       69.2   22.1

# %%
df.head(5).sort_values('TV')
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 2           3   17.2   45.9       69.3    9.3
# 1           2   44.5   39.3       45.1   10.4
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9
# 0           1  230.1   37.8       69.2   22.1

# %%
df.head(5).sort_values('TV',ascending=False)
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 4           5  180.8   10.8       58.4   12.9
# 3           4  151.5   41.3       58.5   18.5
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3

# %%
df.head(5).sort_values(['TV','sales'])
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 2           3   17.2   45.9       69.3    9.3
# 1           2   44.5   39.3       45.1   10.4
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9
# 0           1  230.1   37.8       69.2   22.1

# %%
df.head(5).sort_values(['TV','radio'],ascending=[0,1])
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 4           5  180.8   10.8       58.4   12.9
# 3           4  151.5   41.3       58.5   18.5
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3

# %% [markdown]
# MANIPULATING DATAFRAMES

# %% [raw]
# 1.Adding Columns  data_frame['new_column']=default_value/expression/condition
# 2.Removing Columns  data_frame.drop(columns='column_name')
#                     data_frame.drop(columns='column_name',inplace=True)

# %%
df['Total']=0
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales  Total
# 0             1  230.1   37.8       69.2   22.1      0
# 1             2   44.5   39.3       45.1   10.4      0
# 2             3   17.2   45.9       69.3    9.3      0
# 3             4  151.5   41.3       58.5   18.5      0
# 4             5  180.8   10.8       58.4   12.9      0
# ..          ...    ...    ...        ...    ...    ...
# 195         196   38.2    3.7       13.8    7.6      0
# 196         197   94.2    4.9        8.1    9.7      0
# 197         198  177.0    9.3        6.4   12.8      0
# 198         199  283.6   42.0       66.2   25.5      0
# 199         200  232.1    8.6        8.7   13.4      0
#
# [200 rows x 6 columns]

# %%
df['Total']=df['TV']+df['radio']+df['newspaper']+df['sales']
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales  Total
# 0             1  230.1   37.8       69.2   22.1  359.2
# 1             2   44.5   39.3       45.1   10.4  139.3
# 2             3   17.2   45.9       69.3    9.3  141.7
# 3             4  151.5   41.3       58.5   18.5  269.8
# 4             5  180.8   10.8       58.4   12.9  262.9
# ..          ...    ...    ...        ...    ...    ...
# 195         196   38.2    3.7       13.8    7.6   63.3
# 196         197   94.2    4.9        8.1    9.7  116.9
# 197         198  177.0    9.3        6.4   12.8  205.5
# 198         199  283.6   42.0       66.2   25.5  417.3
# 199         200  232.1    8.6        8.7   13.4  262.8
#
# [200 rows x 6 columns]

# %%
df.drop(columns="Total",inplace=True)
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.shape
# Out:
# (200, 5)

# %% [markdown]
# REMOVING DUPLICATES

# %% [raw]
# 1.Knowing Duplicates    data_frame.duplicated() ----> Boolean Result
# 2.Removing Duplicated   data_frame.frop_duplicates()
#                         data_frame.drop_duplicates(inplace=True)

# %%
import pandas as pd
data=pd.read_csv('Advertising.csv')
df=pd.DataFrame(data)
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.shape
# Out:
# (200, 5)

# %%
df.head(11).duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# dtype: bool

# %%
df.head(11).drop_duplicates()
# Out:
#     Unnamed: 0     TV  radio  newspaper  sales
# 0            1  230.1   37.8       69.2   22.1
# 1            2   44.5   39.3       45.1   10.4
# 2            3   17.2   45.9       69.3    9.3
# 3            4  151.5   41.3       58.5   18.5
# 4            5  180.8   10.8       58.4   12.9
# 5            6    8.7   48.9       75.0    7.2
# 6            7   57.5   32.8       23.5   11.8
# 7            8  120.2   19.6       11.6   13.2
# 8            9    8.6    2.1        1.0    4.8
# 9           10  199.8    2.6       21.2   10.6
# 10          11   66.1    5.8       24.2    8.6

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# HANDLING MISSING DATA

# %% [raw]
# 1.data_frame.dropna()
# 2.data_frame.dropna(inplace=True)
# 3.fill the default values   data_frame.fillna(default_value) -------> NAN

# %%
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.fillna('venky')
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.dropna()
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.dropna(inplace=True)

# %%
DATA FILTERING AND CONDITIONAL CHANGES

# %% [raw]
# 1.data_frame.loc[simple_condition]
# 2.data_frame.loc[compound_codition]
# 3.data_frame.loc[simple_condition.str.contains(str)]
# 4.data_frame.loc[simple_condition.str.startswith(str)]
# 5.data_frame.loc[simple_condition.str.ends with (str)]

# %%
df.head(50).loc[df['sales']>20.4]
# Out:
#     Unnamed: 0     TV  radio  newspaper  sales
# 0            1  230.1   37.8       69.2   22.1
# 15          16  195.4   47.7       52.9   22.4
# 17          18  281.4   39.6       55.8   24.4
# 30          31  292.9   28.3       43.2   21.4
# 36          37  266.9   43.8        5.0   25.4
# 39          40  228.0   37.7       32.0   21.5
# 42          43  293.6   27.7        1.8   20.7
# 47          48  239.9   41.5       18.5   23.2

# %%
df.head(20).loc[df['sales']<20.4]
# Out:
#     Unnamed: 0     TV  radio  newspaper  sales
# 1            2   44.5   39.3       45.1   10.4
# 2            3   17.2   45.9       69.3    9.3
# 3            4  151.5   41.3       58.5   18.5
# 4            5  180.8   10.8       58.4   12.9
# 5            6    8.7   48.9       75.0    7.2
# 6            7   57.5   32.8       23.5   11.8
# 7            8  120.2   19.6       11.6   13.2
# 8            9    8.6    2.1        1.0    4.8
# 9           10  199.8    2.6       21.2   10.6
# 10          11   66.1    5.8       24.2    8.6
# 11          12  214.7   24.0        4.0   17.4
# 12          13   23.8   35.1       65.9    9.2
# 13          14   97.5    7.6        7.2    9.7
# 14          15  204.1   32.9       46.0   19.0
# 16          17   67.8   36.6      114.0   12.5
# 18          19   69.2   20.5       18.3   11.3
# 19          20  147.3   23.9       19.1   14.6

# %%
tdf.head(10).loc[(df['sales']<20.4) & (df['newspaper']<29)]
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 6           7   57.5   32.8       23.5   11.8
# 7           8  120.2   19.6       11.6   13.2
# 8           9    8.6    2.1        1.0    4.8
# 9          10  199.8    2.6       21.2   10.6

# %%
df['Total']=df['TV']+df['radio']+df['newspaper']+df['sales']
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales  Total
# 0             1  230.1   37.8       69.2   22.1  359.2
# 1             2   44.5   39.3       45.1   10.4  139.3
# 2             3   17.2   45.9       69.3    9.3  141.7
# 3             4  151.5   41.3       58.5   18.5  269.8
# 4             5  180.8   10.8       58.4   12.9  262.9
# ..          ...    ...    ...        ...    ...    ...
# 195         196   38.2    3.7       13.8    7.6   63.3
# 196         197   94.2    4.9        8.1    9.7  116.9
# 197         198  177.0    9.3        6.4   12.8  205.5
# 198         199  283.6   42.0       66.2   25.5  417.3
# 199         200  232.1    8.6        8.7   13.4  262.8
#
# [200 rows x 6 columns]

# %%
df['percentage']=(df['Total']/200)
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales  Total  percentage
# 0             1  230.1   37.8       69.2   22.1  359.2      1.7960
# 1             2   44.5   39.3       45.1   10.4  139.3      0.6965
# 2             3   17.2   45.9       69.3    9.3  141.7      0.7085
# 3             4  151.5   41.3       58.5   18.5  269.8      1.3490
# 4             5  180.8   10.8       58.4   12.9  262.9      1.3145
# ..          ...    ...    ...        ...    ...    ...         ...
# 195         196   38.2    3.7       13.8    7.6   63.3      0.3165
# 196         197   94.2    4.9        8.1    9.7  116.9      0.5845
# 197         198  177.0    9.3        6.4   12.8  205.5      1.0275
# 198         199  283.6   42.0       66.2   25.5  417.3      2.0865
# 199         200  232.1    8.6        8.7   13.4  262.8      1.3140
#
# [200 rows x 7 columns]

# %%
df['grade']='pass/fail'
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales  Total  percentage      grade
# 0             1  230.1   37.8       69.2   22.1  359.2      1.7960  pass/fail
# 1             2   44.5   39.3       45.1   10.4  139.3      0.6965  pass/fail
# 2             3   17.2   45.9       69.3    9.3  141.7      0.7085  pass/fail
# 3             4  151.5   41.3       58.5   18.5  269.8      1.3490  pass/fail
# 4             5  180.8   10.8       58.4   12.9  262.9      1.3145  pass/fail
# ..          ...    ...    ...        ...    ...    ...         ...        ...
# 195         196   38.2    3.7       13.8    7.6   63.3      0.3165  pass/fail
# 196         197   94.2    4.9        8.1    9.7  116.9      0.5845  pass/fail
# 197         198  177.0    9.3        6.4   12.8  205.5      1.0275  pass/fail
# 198         199  283.6   42.0       66.2   25.5  417.3      2.0865  pass/fail
# 199         200  232.1    8.6        8.7   13.4  262.8      1.3140  pass/fail
#
# [200 rows x 8 columns]

# %% [markdown]
# EXPORT DATAFRAME TO EXCEL,CSV AND TEXT FILE

# %% [raw]
# 1.data_frame.to_excel(path)
# 2.data_frame.to_excel(path,index=false)
# 3.data_frame.to_csv(path)
# 4.data_frame.to_csv(path,index=false)
