# %%
import pandas as pd
df=pd.read_csv('C:\\Users\\91630\\OneDrive\\Desktop\\insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df['sex'].value_counts()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
x=df['sex']

# %%
x
# Out:
# 0       female
# 1         male
# 2         male
# 3         male
# 4         male
#          ...
# 1333      male
# 1334    female
# 1335    female
# 1336    female
# 1337    female
# Name: sex, Length: 1338, dtype: object

# %%
y=df[['sex','children']]
y
# Out:
#          sex  children
# 0     female         0
# 1       male         1
# 2       male         3
# 3       male         0
# 4       male         0
# ...      ...       ...
# 1333    male         3
# 1334  female         0
# 1335  female         0
# 1336  female         0
# 1337  female         0
#
# [1338 rows x 2 columns]

# %%
df.size
# Out:
# 9366

# %%
x.size
# Out:
# 2676

# %%
x.describe()
# Out:
#           children
# count  1338.000000
# mean      1.094918
# std       1.205493
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       2.000000
# max       5.000000

# %%
x[2:9]
# Out:
#       sex  children
# 2    male         3
# 3    male         0
# 4    male         0
# 5  female         0
# 6  female         1
# 7  female         3
# 8    male         2

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.size
# Out:
# 9366

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.isna()
# Out:
#         age    sex    bmi  children  smoker  region  charges
# 0     False  False  False     False   False   False    False
# 1     False  False  False     False   False   False    False
# 2     False  False  False     False   False   False    False
# 3     False  False  False     False   False   False    False
# 4     False  False  False     False   False   False    False
# ...     ...    ...    ...       ...     ...     ...      ...
# 1333  False  False  False     False   False   False    False
# 1334  False  False  False     False   False   False    False
# 1335  False  False  False     False   False   False    False
# 1336  False  False  False     False   False   False    False
# 1337  False  False  False     False   False   False    False
#
# [1338 rows x 7 columns]

# %%
df.sum()
# Out:
# age                                                     52459
# sex         femalemalemalemalemalefemalefemalefemalemalefe...
# bmi                                                 41027.625
# children                                                 1465
# smoker      yesnonononononononononoyesnonoyesnonononoyesno...
# region      southwestsoutheastsoutheastnorthwestnorthwests...
# charges                                       17755824.990759
# dtype: object

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df['sex'].isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1333    False
# 1334    False
# 1335    False
# 1336    False
# 1337    False
# Name: sex, Length: 1338, dtype: bool

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
x=df[['age','charges']]
x.head()
# Out:
#    age      charges
# 0   19  16884.92400
# 1   18   1725.55230
# 2   28   4449.46200
# 3   33  21984.47061
# 4   32   3866.85520

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df['sex']=='male'
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1333     True
# 1334    False
# 1335    False
# 1336    False
# 1337    False
# Name: sex, Length: 1338, dtype: bool

# %%
y=df['sex']=='female'
z=df[y]
z[['sex','children']]
# Out:
#          sex  children
# 0     female         0
# 5     female         0
# 6     female         1
# 7     female         3
# 9     female         0
# ...      ...       ...
# 1332  female         3
# 1334  female         0
# 1335  female         0
# 1336  female         0
# 1337  female         0
#
# [662 rows x 2 columns]

# %%
df.sample(2)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1050   44  female  36.955         1     no  northwest   8023.13545
# 225    55    male  33.880         3     no  southeast  11987.16820

# %%
l=df[df['region']=='southwest']
l.head()
# Out:
#     age     sex   bmi  children smoker     region    charges
# 0    19  female  27.9         0    yes  southwest  16884.924
# 12   23    male  34.4         0     no  southwest   1826.843
# 15   19    male  24.6         1     no  southwest   1837.237
# 18   56    male  40.3         0     no  southwest  10602.385
# 19   30    male  35.3         0    yes  southwest  36837.467

# %%
l.size
# Out:
# 2275

# %%
df['region'].unique()
df[df['region']=='southwest'].shape[0]
# Out:
# 325

# %%
len(df[df['region']=='southwest'])
# Out:
# 325

# %%
l.shape
# Out:
# (325, 7)

# %%
df.std()
# Out:
# C:\Windows\Temp\ipykernel_13208\3390915376.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# age            14.049960
# bmi             6.098187
# children        1.205493
# charges     12110.011237
# dtype: float64

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.sort_values('age').head()
# Out:
#       age     sex    bmi  children smoker     region      charges
# 1248   18  female  39.82         0     no  southeast   1633.96180
# 482    18  female  31.35         0     no  southeast   1622.18850
# 492    18  female  25.08         0     no  northeast   2196.47320
# 525    18  female  33.88         0     no  southeast  11482.63485
# 529    18    male  25.46         0     no  northeast   1708.00140

# %%
df.sort_values('age',ascending=False).head()
# Out:
#       age     sex     bmi  children smoker     region      charges
# 335    64    male  34.500         0     no  southwest  13822.80300
# 603    64  female  39.050         3     no  southeast  16085.12750
# 752    64    male  37.905         0     no  northwest  14210.53595
# 1265   64    male  23.760         0    yes  southeast  26926.51440
# 534    64    male  40.480         0     no  southeast  13831.11520

# %%
df.sort_values(['age','charges']).head()
# Out:
#       age   sex    bmi  children smoker     region    charges
# 940    18  male  23.21         0     no  southeast  1121.8739
# 808    18  male  30.14         0     no  southeast  1131.5066
# 1244   18  male  33.33         0     no  southeast  1135.9407
# 663    18  male  33.66         0     no  southeast  1136.3994
# 22     18  male  34.10         0     no  southeast  1137.0110

# %%
df.sort_values(['age','charges'],ascending=False).head()
# Out:
#       age     sex    bmi  children smoker     region      charges
# 1241   64    male  36.96         2    yes  southeast  49577.66240
# 328    64  female  33.80         1    yes  southwest  47928.03000
# 94     64  female  31.30         2    yes  southwest  47291.05500
# 420    64    male  33.88         0    yes  southeast  46889.26120
# 62     64    male  24.70         1     no  northwest  30166.61817

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1333    False
# 1334    False
# 1335    False
# 1336    False
# 1337    False
# Length: 1338, dtype: bool

# %%
df.drop_duplicates()
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
df.drop_duplicates(inplace=True)

# %%
df.loc[df['age']>58].head()
# Out:
#     age     sex     bmi  children smoker     region      charges
# 9    60  female  25.840         0     no  northwest  28923.13692
# 11   62  female  26.290         0    yes  southeast  27808.72510
# 20   60  female  36.005         0     no  northeast  13228.84695
# 25   59  female  27.720         3     no  southeast  14001.13380
# 26   63  female  23.085         0     no  northeast  14451.83515

# %%
df.loc[df['age']<59].head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.loc[(df['age']<40) & (df['charges']>21984.47061)].head()
# Out:
#     age     sex    bmi  children smoker     region     charges
# 14   27    male  42.13         0    yes  southeast  39611.7577
# 19   30    male  35.30         0    yes  southwest  36837.4670
# 23   34  female  31.92         1    yes  northeast  37701.8768
# 29   31    male  36.30         2    yes  southwest  38711.0000
# 30   22    male  35.60         0    yes  southwest  35585.5760

# %%
df.loc[df['smoker'].str.contains('yes')].head()
# Out:
#     age     sex    bmi  children smoker     region     charges
# 0    19  female  27.90         0    yes  southwest  16884.9240
# 11   62  female  26.29         0    yes  southeast  27808.7251
# 14   27    male  42.13         0    yes  southeast  39611.7577
# 19   30    male  35.30         0    yes  southwest  36837.4670
# 23   34  female  31.92         1    yes  northeast  37701.8768

# %%
df.loc[df['region'].str.startswith('s')].head()
# Out:
#    age     sex    bmi  children smoker     region     charges
# 0   19  female  27.90         0    yes  southwest  16884.9240
# 1   18    male  33.77         1     no  southeast   1725.5523
# 2   28    male  33.00         3     no  southeast   4449.4620
# 5   31  female  25.74         0     no  southeast   3756.6216
# 6   46  female  33.44         1     no  southeast   8240.5896

# %%
df.loc[df['smoker'].str.endswith('s')].head()
# Out:
#     age     sex    bmi  children smoker     region     charges
# 0    19  female  27.90         0    yes  southwest  16884.9240
# 11   62  female  26.29         0    yes  southeast  27808.7251
# 14   27    male  42.13         0    yes  southeast  39611.7577
# 19   30    male  35.30         0    yes  southwest  36837.4670
# 23   34  female  31.92         1    yes  northeast  37701.8768

# %%
df['Total']=df['bmi']+df['charges']
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges        Total
# 0   19  female  27.900         0    yes  southwest  16884.92400  16912.82400
# 1   18    male  33.770         1     no  southeast   1725.55230   1759.32230
# 2   28    male  33.000         3     no  southeast   4449.46200   4482.46200
# 3   33    male  22.705         0     no  northwest  21984.47061  22007.17561
# 4   32    male  28.880         0     no  northwest   3866.85520   3895.73520

# %%
df['percentage']=(df['Total']/500)
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges        Total  \
# 0   19  female  27.900         0    yes  southwest  16884.92400  16912.82400
# 1   18    male  33.770         1     no  southeast   1725.55230   1759.32230
# 2   28    male  33.000         3     no  southeast   4449.46200   4482.46200
# 3   33    male  22.705         0     no  northwest  21984.47061  22007.17561
# 4   32    male  28.880         0     no  northwest   3866.85520   3895.73520
#
#    percentage
# 0   33.825648
# 1    3.518645
# 2    8.964924
# 3   44.014351
# 4    7.791470

# %%
df['Grade']='pass/fail'
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges        Total  \
# 0   19  female  27.900         0    yes  southwest  16884.92400  16912.82400
# 1   18    male  33.770         1     no  southeast   1725.55230   1759.32230
# 2   28    male  33.000         3     no  southeast   4449.46200   4482.46200
# 3   33    male  22.705         0     no  northwest  21984.47061  22007.17561
# 4   32    male  28.880         0     no  northwest   3866.85520   3895.73520
#
#    percentage      Grade
# 0   33.825648  pass/fail
# 1    3.518645  pass/fail
# 2    8.964924  pass/fail
# 3   44.014351  pass/fail
# 4    7.791470  pass/fail

# %%
df.drop(columns='Grade').head()
# Out:
#    age     sex     bmi  children smoker     region      charges        Total  \
# 0   19  female  27.900         0    yes  southwest  16884.92400  16912.82400
# 1   18    male  33.770         1     no  southeast   1725.55230   1759.32230
# 2   28    male  33.000         3     no  southeast   4449.46200   4482.46200
# 3   33    male  22.705         0     no  northwest  21984.47061  22007.17561
# 4   32    male  28.880         0     no  northwest   3866.85520   3895.73520
#
#    percentage
# 0   33.825648
# 1    3.518645
# 2    8.964924
# 3   44.014351
# 4    7.791470

# %%
df.drop(columns='Total',inplace=False).head()
# Out:
#    age     sex     bmi  children smoker     region      charges  percentage  \
# 0   19  female  27.900         0    yes  southwest  16884.92400   33.825648
# 1   18    male  33.770         1     no  southeast   1725.55230    3.518645
# 2   28    male  33.000         3     no  southeast   4449.46200    8.964924
# 3   33    male  22.705         0     no  northwest  21984.47061   44.014351
# 4   32    male  28.880         0     no  northwest   3866.85520    7.791470
#
#        Grade
# 0  pass/fail
# 1  pass/fail
# 2  pass/fail
# 3  pass/fail
# 4  pass/fail

# %%
for rec in df.iterrows():
    print(rec)
# Out:
# (0, age                  19
# sex              female
# bmi                27.9
# children              0
# smoker              yes
# region        southwest
# charges       16884.924
# Total         16912.824
# percentage    33.825648
# Grade         pass/fail
# Name: 0, dtype: object)
# (1, age                  18
# sex                male
# bmi               33.77
# children              1
# smoker               no
# region        southeast
# charges       1725.5523
# Total         1759.3223
# percentage     3.518645
# Grade         pass/fail
# Name: 1, dtype: object)
# (2, age                  28
# sex                male
# bmi                33.0
# children              3
# smoker               no
# region        southeast
# charges        4449.462
# Total          4482.462
# percentage     8.964924
# Grade         pass/fail
# Name: 2, dtype: object)
# (3, age                    33
# sex                  male
# bmi                22.705
# children                0
# ...

# %%
df['charges'].head()
# Out:
# 0    16884.92400
# 1     1725.55230
# 2     4449.46200
# 3    21984.47061
# 4     3866.85520
# Name: charges, dtype: float64

# %%
df[6:20:3]
# Out:
#     age     sex    bmi  children smoker     region      charges        Total  \
# 6    46  female  33.44         1     no  southeast   8240.58960   8274.02960
# 9    60  female  25.84         0     no  northwest  28923.13692  28948.97692
# 12   23    male  34.40         0     no  southwest   1826.84300   1861.24300
# 15   19    male  24.60         1     no  southwest   1837.23700   1861.83700
# 18   56    male  40.30         0     no  southwest  10602.38500  10642.68500
#
#     percentage      Grade
# 6    16.548059  pass/fail
# 9    57.897954  pass/fail
# 12    3.722486  pass/fail
# 15    3.723674  pass/fail
# 18   21.285370  pass/fail

# %%
df[['age','sex','Total']]
# Out:
#       age     sex        Total
# 0      19  female  16912.82400
# 1      18    male   1759.32230
# 2      28    male   4482.46200
# 3      33    male  22007.17561
# 4      32    male   3895.73520
# ...   ...     ...          ...
# 1333   50    male  10631.51830
# 1334   18  female   2237.90080
# 1335   18  female   1666.68350
# 1336   21  female   2033.74500
# 1337   61  female  29170.43030
#
# [1337 rows x 3 columns]

# %%
df[['age','sex','Total']][4:40:4]
# Out:
#     age     sex        Total
# 4    32    male   3895.73520
# 8    37    male   6436.24070
# 12   23    male   1861.24300
# 16   52  female  10828.11620
# 20   60  female  13264.85195
# 24   37    male   6231.92675
# 28   23    male   2792.57715
# 32   19  female   4716.39700
# 36   62  female  15645.15835

# %%
df.loc[19]
# Out:
# age                  30
# sex                male
# bmi                35.3
# children              0
# smoker              yes
# region        southwest
# charges       36837.467
# Total         36872.767
# percentage    73.745534
# Grade         pass/fail
# Name: 19, dtype: object

# %%
df.loc[19,['age','children']]
# Out:
# age         30
# children     0
# Name: 19, dtype: object

# %%
df.loc[10:20]
# Out:
#     age     sex     bmi  children smoker     region      charges        Total  \
# 10   25    male  26.220         0     no  northeast   2721.32080   2747.54080
# 11   62  female  26.290         0    yes  southeast  27808.72510  27835.01510
# 12   23    male  34.400         0     no  southwest   1826.84300   1861.24300
# 13   56  female  39.820         0     no  southeast  11090.71780  11130.53780
# 14   27    male  42.130         0    yes  southeast  39611.75770  39653.88770
# 15   19    male  24.600         1     no  southwest   1837.23700   1861.83700
# 16   52  female  30.780         1     no  northeast  10797.33620  10828.11620
# 17   23    male  23.845         0     no  northeast   2395.17155   2419.01655
# 18   56    male  40.300         0     no  southwest  10602.38500  10642.68500
# 19   30    male  35.300         0    yes  southwest  36837.46700  36872.76700
# 20   60  female  36.005         0     no  northeast  13228.84695  13264.85195
#
#     percentage      Grade
# ...

# %%
df.loc[0:3,['age']]
# Out:
#    age
# 0   19
# 1   18
# 2   28
# 3   33

# %%
#progress bar
from tqdm.notebook import tqdm
for x in tqdm(range(10000000)):
    pass
# Out:
#   0%|          | 0/10000000 [00:00<?, ?it/s]

# %%
#merge the two datasets
import pandas as pd
d1={'Name':['venky','shyam','chandu','bhargav'],'age':[21,22,20,22],'Address':['Ramachadrapuram','Ravalapalem','Gunter','Anathapuram']}
d2={'Name':['geetha','sowmya','priya','sony'],'age':[19,21,20,22],'Address':['Hyderabad','Amalapuram','vizag','mumbai']}
data1=pd.DataFrame(d1)
data2=pd.DataFrame(d2)
data1
#data2
#res1=pd.concat([data1,data2],axis=1,join='inner')
#res1
# Out:
#      Name  age     Address
# 0  geetha   19   Hyderabad
# 1  sowmya   21  Amalapuram
# 2   priya   20       vizag
# 3    sony   22      mumbai

# %%
data1
# Out:
#       Name  age          Address
# 0    venky   21  Ramachadrapuram
# 1    shyam   22      Ravalapalem
# 2   chandu   20           Gunter
# 3  bhargav   22      Anathapuram

# %%
data2
# Out:
#      Name  age     Address
# 0  geetha   19   Hyderabad
# 1  sowmya   21  Amalapuram
# 2   priya   20       vizag
# 3    sony   22      mumbai

# %%
res=[data1,data2]
res=pd.concat([data1,data2],axis=1,join='inner')
res
# Out:
#       Name  age          Address    Name  age     Address
# 0    venky   21  Ramachadrapuram  geetha   19   Hyderabad
# 1    shyam   22      Ravalapalem  sowmya   21  Amalapuram
# 2   chandu   20           Gunter   priya   20       vizag
# 3  bhargav   22      Anathapuram    sony   22      mumbai

# %%
res=pd.concat([data1],ignore_index=True)
# Out:
#       Name  age          Address
# 0    venky   21  Ramachadrapuram
# 1    shyam   22      Ravalapalem
# 2   chandu   20           Gunter
# 3  bhargav   22      Anathapuram
