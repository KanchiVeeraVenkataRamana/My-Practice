# %%
# !wget 'https://th.bing.com/th/id/OIP.M6acAhueNKPF0Ou5vKYfpwHaF4?w=252&h=200&c=7&r=0&o=5&dpr=1.5&pid=1.7'
# Out:
# --2023-06-01 06:30:44--  https://th.bing.com/th/id/OIP.M6acAhueNKPF0Ou5vKYfpwHaF4?w=252&h=200&c=7&r=0&o=5&dpr=1.5&pid=1.7
# Resolving th.bing.com (th.bing.com)... 23.52.40.106, 23.52.40.90, 2600:1413:1::6011:b42e, ...
# Connecting to th.bing.com (th.bing.com)|23.52.40.106|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12834 (13K) [image/jpeg]
# Saving to: ‘OIP.M6acAhueNKPF0Ou5vKYfpwHaF4?w=252&h=200&c=7&r=0&o=5&dpr=1.5&pid=1.7’
#
# OIP.M6acAhueNKPF0Ou 100%[===================>]  12.53K  --.-KB/s    in 0s
#
# 2023-06-01 06:30:44 (142 MB/s) - ‘OIP.M6acAhueNKPF0Ou5vKYfpwHaF4?w=252&h=200&c=7&r=0&o=5&dpr=1.5&pid=1.7’ saved [12834/12834]

# %%
# !wget 'https://th.bing.com/th/id/OIP.Jf0NnGpH2AhNM3BtwZufwwHaJ4?pid=ImgDet&rs=1'
# Out:
# --2023-06-01 07:10:47--  https://th.bing.com/th/id/OIP.Jf0NnGpH2AhNM3BtwZufwwHaJ4?pid=ImgDet&rs=1
# Resolving th.bing.com (th.bing.com)... 204.79.197.200, 13.107.21.200, 2620:1ec:c11::200
# Connecting to th.bing.com (th.bing.com)|204.79.197.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22858 (22K) [image/jpeg]
# Saving to: ‘OIP.Jf0NnGpH2AhNM3BtwZufwwHaJ4?pid=ImgDet&rs=1.1’
#
# OIP.Jf0NnGpH2AhNM3B 100%[===================>]  22.32K  --.-KB/s    in 0s
#
# 2023-06-01 07:10:47 (413 MB/s) - ‘OIP.Jf0NnGpH2AhNM3BtwZufwwHaJ4?pid=ImgDet&rs=1.1’ saved [22858/22858]

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as pt

# %%
img = mpimg.imread('/content/Dog')
img
# Out:
# array([[[ 85,  97,  35],
#         [ 85,  97,  35],
#         [ 85,  97,  35],
#         ...,
#         [182, 159,  83],
#         [182, 159,  83],
#         [182, 159,  83]],
#
#        [[ 85,  95,  34],
#         [ 85,  95,  34],
#         [ 85,  95,  34],
#         ...,
#         [180, 158,  82],
#         [179, 157,  81],
#         [179, 157,  81]],
#
#        [[ 84,  94,  33],
#         [ 84,  94,  33],
#         [ 84,  94,  31],
#         ...,
#         [178, 156,  80],
#         [177, 155,  79],
#         [177, 155,  79]],
#
#        ...,
#
#        [[ 37,  53,  16],
#         [ 27,  43,   4],
#         [ 25,  41,   2],
#         ...,
#         [ 14,  22,   7],
#         [  5,  13,   0],
#         [ 19,  27,  14]],
#
#        [[ 49,  65,  28],
#         [ 32,  48,  11],
#         [ 22,  38,   0],
#         ...,
#         [ 18,  27,  10],
#         [ 25,  33,  18],
#         [ 46,  54,  39]],
#
#        [[ 61,  77,  41],
#         [ 37,  53,  17],
#         [ 21,  37,   0],
# ...

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (632, 474, 3)

# %%
#pt.figure(figsize= (5,3))
img_plot = pt.imshow(img)
pt.show()

# %%
from PIL import Image
img = Image.open('/content/Dog')
img_resized = img.resize((200,200))

# %%
img_resized.save('dog_image_resized.jpg')

# %%
img_res = mpimg.imread('/content/dog_image_resized.jpg')
img_res_plot = pt.imshow(img_res)
pt.show()

# %%
img_res.shape
# Out:
# (200, 200, 3)

# %%
import cv2
img = cv2.imread('/content/Dog')
img
# Out:
# array([[[ 35,  97,  85],
#         [ 35,  97,  85],
#         [ 35,  97,  85],
#         ...,
#         [ 83, 159, 182],
#         [ 83, 159, 182],
#         [ 83, 159, 182]],
#
#        [[ 34,  96,  84],
#         [ 34,  96,  84],
#         [ 34,  96,  84],
#         ...,
#         [ 82, 158, 181],
#         [ 81, 157, 180],
#         [ 81, 157, 180]],
#
#        [[ 33,  94,  84],
#         [ 33,  94,  84],
#         [ 31,  94,  84],
#         ...,
#         [ 81, 156, 178],
#         [ 80, 155, 177],
#         [ 80, 155, 177]],
#
#        ...,
#
#        [[ 16,  53,  37],
#         [  4,  43,  27],
#         [  2,  41,  25],
#         ...,
#         [  7,  22,  14],
#         [  0,  13,   5],
#         [ 14,  27,  19]],
#
#        [[ 29,  65,  49],
#         [ 11,  48,  32],
#         [  0,  38,  22],
#         ...,
#         [ 10,  27,  18],
#         [ 18,  33,  25],
#         [ 39,  54,  46]],
#
#        [[ 41,  77,  61],
#         [ 16,  53,  37],
#         [  0,  37,  21],
# ...

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (632, 474, 3)

# %%
greyscale_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
type(greyscale_image)
# Out:
# numpy.ndarray

# %%
greyscale_image.shape
# Out:
# (632, 474)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(greyscale_image)
# Out:
# <PIL.Image.Image image mode=L size=474x632 at 0x7F2AAB238B80>

# %%
cv2.imwrite('dog_greyscale_image.jpg', greyscale_image)
# Out:
# True
